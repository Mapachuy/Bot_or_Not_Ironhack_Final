# %% [markdown]
# # Data Cleaning

# %%
import pandas as panditasbb
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = panditasbb.read_csv('../bot_detector/twitter_human_bots_dataset.csv')

# %%
df
# Out:
#        Unnamed: 0           created_at  default_profile  \
# 0               0  2016-10-15 21:32:11            False
# 1               1  2016-11-09 05:01:30            False
# 2               2  2017-06-17 05:34:27            False
# 3               3  2016-07-21 13:32:25             True
# 4               4  2012-01-15 16:32:35            False
# ...           ...                  ...              ...
# 37433       37433  2009-08-08 13:11:15             True
# 37434       37434  2013-01-05 21:35:37            False
# 37435       37435  2013-01-14 18:05:54             True
# 37436       37436  2012-09-10 16:12:02            False
# 37437       37437  2011-12-12 12:59:28            False
#
#        default_profile_image  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 37433                  False
# 37434                  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37438 entries, 0 to 37437
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    37438 non-null  int64
#  1   created_at                    37438 non-null  object
#  2   default_profile               37438 non-null  bool
#  3   default_profile_image         37438 non-null  bool
#  4   description                   30182 non-null  object
#  5   favourites_count              37438 non-null  int64
#  6   followers_count               37438 non-null  int64
#  7   friends_count                 37438 non-null  int64
#  8   geo_enabled                   37438 non-null  bool
#  9   id                            37438 non-null  int64
#  10  lang                          29481 non-null  object
#  11  location                      37435 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  favourites_count  followers_count  friends_count  \
# count  37438.000000      37438.000000     3.743800e+04   3.743800e+04
# mean   18718.500000      12302.062183     3.703098e+05   4.445925e+03
# std    10807.564026      33923.650237     2.470829e+06   4.954520e+04
# min        0.000000          0.000000     0.000000e+00   0.000000e+00
# 25%     9359.250000        362.000000     3.500000e+01   3.700000e+01
# 50%    18718.500000       2066.000000     3.650000e+02   2.960000e+02
# 75%    28077.750000       8879.000000     8.440250e+03   8.930000e+02
# max    37437.000000     885123.000000     1.216415e+08   4.343060e+06
#
#                  id  statuses_count  average_tweets_per_day  account_age_days
# count  3.743800e+04    3.743800e+04            37438.000000      37438.000000
# mean   1.221536e+17    2.107339e+04                6.891668       3022.128052
# std    3.004313e+17    6.732977e+04               24.580116       1013.695870
# ...

# %% [markdown]
# ## Para 2 features

# %%
df.drop(columns=['average_tweets_per_day','account_age_days','verified','statuses_count','screen_name','profile_image_url','profile_background_image_url','location','lang','id','geo_enabled','favourites_count','description','default_profile_image','default_profile','created_at','Unnamed: 0'],inplace=True)

# %%
df
# Out:
#        followers_count  friends_count account_type
# 0                 1589              4          bot
# 1                  860            880        human
# 2                  172            594        human
# 3                  517            633        human
# 4               753678            116        human
# ...                ...            ...          ...
# 37433              139           1105        human
# 37434          1121486            605        human
# 37435            85630            190        human
# 37436              138            166        human
# 37437                5             39          bot
#
# [37438 rows x 3 columns]

# %%
df.account_type.value_counts()
# Out:
# human    25013
# bot      12425
# Name: account_type, dtype: int64

# %%
df.replace(to_replace=['human', 'bot'], value=[0,1], inplace=True)

# %%
df
# Out:
#        followers_count  friends_count  account_type
# 0                 1589              4             1
# 1                  860            880             0
# 2                  172            594             0
# 3                  517            633             0
# 4               753678            116             0
# ...                ...            ...           ...
# 37433              139           1105             0
# 37434          1121486            605             0
# 37435            85630            190             0
# 37436              138            166             0
# 37437                5             39             1
#
# [37438 rows x 3 columns]

# %%
df.account_type.value_counts()
# Out:
# 0    25013
# 1    12425
# Name: account_type, dtype: int64

# %%
df.rename(columns={'account_type':'Bot_or_Not'}, inplace=True)

# %%
df
# Out:
#        followers_count  friends_count  Bot_or_Not
# 0                 1589              4           1
# 1                  860            880           0
# 2                  172            594           0
# 3                  517            633           0
# 4               753678            116           0
# ...                ...            ...         ...
# 37433              139           1105           0
# 37434          1121486            605           0
# 37435            85630            190           0
# 37436              138            166           0
# 37437                5             39           1
#
# [37438 rows x 3 columns]

# %%
# df.to_csv('twitter_dataset.csv', index=False)

# %% [markdown]
# ## Para más features

# %%
df_complete = panditasbb.read_csv('../bot_detector/twitter_human_bots_dataset.csv')

# %%
df_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37438 entries, 0 to 37437
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    37438 non-null  int64
#  1   created_at                    37438 non-null  object
#  2   default_profile               37438 non-null  bool
#  3   default_profile_image         37438 non-null  bool
#  4   description                   30182 non-null  object
#  5   favourites_count              37438 non-null  int64
#  6   followers_count               37438 non-null  int64
#  7   friends_count                 37438 non-null  int64
#  8   geo_enabled                   37438 non-null  bool
#  9   id                            37438 non-null  int64
#  10  lang                          29481 non-null  object
#  11  location                      37435 non-null  object
# ...

# %%
df_complete.drop(columns=['Unnamed: 0','created_at','description','id','lang','location','profile_background_image_url','profile_image_url','screen_name'], inplace=True)

# %%
df_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37438 entries, 0 to 37437
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   default_profile         37438 non-null  bool
#  1   default_profile_image   37438 non-null  bool
#  2   favourites_count        37438 non-null  int64
#  3   followers_count         37438 non-null  int64
#  4   friends_count           37438 non-null  int64
#  5   geo_enabled             37438 non-null  bool
#  6   statuses_count          37438 non-null  int64
#  7   verified                37438 non-null  bool
#  8   average_tweets_per_day  37438 non-null  float64
#  9   account_age_days        37438 non-null  int64
#  10  account_type            37438 non-null  object
# dtypes: bool(4), float64(1), int64(5), object(1)
# memory usage: 2.1+ MB

# %%
df_complete.rename(columns={'account_type':'Bot_or_Not'}, inplace=True)

# %%
df_complete.replace(to_replace=['human', 'bot'], value=[0,1], inplace=True)

# %%
df_complete
# Out:
#        default_profile  default_profile_image  favourites_count  \
# 0                False                  False                 4
# 1                False                  False               536
# 2                False                  False              3307
# 3                 True                  False              8433
# 4                False                  False                88
# ...                ...                    ...               ...
# 37433             True                  False               651
# 37434            False                  False              8839
# 37435             True                  False               399
# 37436            False                  False               967
# 37437            False                  False              1092
#
#        followers_count  friends_count  geo_enabled  statuses_count  verified  \
# 0                 1589              4        False           11041     False
# ...

# %%
df_complete.replace(to_replace=[False, True], value=[0,1], inplace=True)

# %%
corr=df_complete.corr(method='pearson')
mask = np.triu(np.ones_like(corr, dtype=np.bool))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
plt.figure(figsize=(10,10))
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},xticklabels=corr.columns.values,yticklabels=corr.columns.values)

# %%
df_complete
# Out:
#        default_profile  default_profile_image  favourites_count  \
# 0                    0                      0                 4
# 1                    0                      0               536
# 2                    0                      0              3307
# 3                    1                      0              8433
# 4                    0                      0                88
# ...                ...                    ...               ...
# 37433                1                      0               651
# 37434                0                      0              8839
# 37435                1                      0               399
# 37436                0                      0               967
# 37437                0                      0              1092
#
#        followers_count  friends_count  geo_enabled  statuses_count  verified  \
# 0                 1589              4            0           11041         0
# ...

# %%
# df_complete.to_csv('twitter_complete_dataset.csv', index=False)
